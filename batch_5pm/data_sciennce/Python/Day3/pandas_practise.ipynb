# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
arr = np.random.random(100)*7.5

# %%
arr.mean()
# Out:
# 3.6342413158635662

# %%
series = pd.Series(data=arr)

# %%
series
# Out:
# 0     1.543856
# 1     6.184809
# 2     5.938384
# 3     3.966238
# 4     3.636975
# 5     6.903214
# 6     5.266620
# 7     7.489925
# 8     1.674429
# 9     6.610464
# 10    6.875658
# 11    0.380316
# 12    1.899925
# 13    0.175264
# 14    6.688414
# 15    0.479993
# 16    3.917777
# 17    7.449550
# 18    2.185811
# 19    1.492526
# 20    3.975963
# 21    4.005127
# 22    0.539260
# 23    0.733443
# 24    5.764118
# 25    1.897350
# 26    5.749263
# 27    3.141367
# 28    4.206390
# 29    3.368953
#         ...
# 70    7.219074
# 71    7.400828
# 72    5.643610
# 73    2.113057
# 74    6.583065
# 75    1.139249
# 76    4.024439
# 77    2.574431
# 78    6.629037
# 79    5.528224
# 80    4.921088
# 81    1.646052
# 82    4.639615
# 83    0.248373
# 84    5.174620
# 85    0.624688
# 86    0.370438
# 87    6.302010
# 88    7.373239
# 89    3.700094
# 90    6.404574
# 91    1.621115
# 92    1.576995
# 93    7.364286
# 94    6.307775
# 95    0.515454
# 96    1.029835
# 97    0.778360
# 98    5.749606
# 99    1.788424
# Length: 100, dtype: float64

# %%
series.plot(kind='bar')

# %%
s = pd.Series([2,3,5,2,3,3,3,3,5,4,3,2,1,1,2,3,4,5])

# %%
s.plot(kind='bar')

# %%
s.hist()

# %%
series.hist()

# %%
s.value_counts()
# Out:
# 3    7
# 2    4
# 5    3
# 4    2
# 1    2
# dtype: int64

# %%
plt.scatter(s.unique(),s.value_counts())
plt.grid()
plt.show()

# %%
s.unique().sort()

# %%
s
# Out:
# 0     2
# 1     3
# 2     5
# 3     2
# 4     3
# 5     3
# 6     3
# 7     3
# 8     5
# 9     4
# 10    3
# 11    2
# 12    1
# 13    1
# 14    2
# 15    3
# 16    4
# 17    5
# dtype: int64

# %%
data = { 
    'Name' : [ 'x','y','z','p','q','r','s','t','p'],
    'Age' : [ 22,25,18,16,32,28,18,19,21],
    'Height' : [ 5.5,2.5,6.2,5.10,5.5,5.6,5.7,5.5,5.8],
    'Weight' : [ 50,60,65,75,40,56,65,78,87]
    
            }

df = pd.DataFrame(data=data,index=range(1,10),columns=data.keys())

# %%
df
# Out:
#   Name  Age  Height  Weight
# 1    x   22     5.5      50
# 2    y   25     2.5      60
# 3    z   18     6.2      65
# 4    p   16     5.1      75
# 5    q   32     5.5      40
# 6    r   28     5.6      56
# 7    s   18     5.7      65
# 8    t   19     5.5      78
# 9    p   21     5.8      87

# %%
df.plot()

# %%
date = [ '2018/12/10','2018/12/11','2018/12/12','2018/12/13','2018/12/14',]

# %%
s = pd.Series(date,dtype='datetime64[ns]')

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.dtype
# Out:
# dtype('<M8[ns]')

# %%
print(s)
# Out:
# 0   2018-12-10
# 1   2018-12-11
# 2   2018-12-12
# 3   2018-12-13
# 4   2018-12-14
# dtype: datetime64[ns]

# %%
d = { 
    'one' : np.random.normal(30.5,5.0,1000),
    'two' : np.random.normal(25,2.5,1000),
    'three' : np.random.binomial(25,.6,1000)
    }

# %%
df = pd.DataFrame(data=d,columns=d.keys())

# %%
df
# Out:
#            one        two  three
# 0    24.844860  24.242688     16
# 1    25.495398  29.520541     17
# 2    29.854776  24.563702     19
# 3    29.318281  24.064152     17
# 4    27.859167  26.546887     16
# 5    29.019029  27.682775     18
# 6    27.901481  26.856199     14
# 7    39.496588  23.005510     16
# 8    31.810976  23.549107     13
# 9    30.296350  18.931895     15
# 10   30.151727  25.904404     16
# 11   28.284846  27.361762     13
# 12   29.982412  27.642459     17
# 13   30.266365  22.277801     15
# 14   34.000566  21.109940     17
# 15   37.709550  23.008048     17
# 16   30.973356  25.964117     14
# 17   28.265518  24.489780     12
# 18   27.799012  28.086853     17
# 19   41.381235  28.580313     17
# 20   27.978102  19.896283     14
# 21   25.681074  27.687181     17
# 22   22.432442  25.188890     12
# 23   29.710664  25.406937     15
# 24   35.673213  22.744418     17
# 25   35.369241  26.735862     17
# 26   28.363112  26.507914     19
# 27   27.456652  23.211546     13
# 28   28.893084  20.932683     17
# 29   39.098423  23.168840     15
# ..         ...        ...    ...
# 970  30.059113  23.476704     19
# 971  27.983089  24.290145     16
# 972  30.310636  26.670812     18
# 973  34.174980  18.582125     17
# 974  36.673764  29.178878     15
# 975  33.473019  24.149343     14
# 976  36.615985  22.499271     14
# 977  29.998854  30.405379     20
# 978  30.370980  27.650650     14
# 979  33.484428  25.157916     12
# 980  32.810186  22.564076     13
# 981  18.683912  22.980432     16
# 982  34.751934  26.483901     18
# 983  32.350280  28.996001     16
# 984  25.124494  26.158541     14
# 985  22.170212  27.967525     17
# 986  24.801547  29.499258     15
# 987  42.307361  25.576739     12
# 988  23.449060  23.202130     16
# 989  30.370354  24.774942     14
# 990  27.636181  24.260771     12
# 991  37.080736  22.633751     14
# 992  33.895452  28.840182     18
# 993  18.146541  27.449014     15
# 994  23.379142  24.874657     14
# 995  29.389368  26.318110     14
# 996  22.312277  27.612347     12
# 997  29.333433  24.293725     15
# 998  29.890832  23.086329     15
# 999  18.926483  26.349100     14
#
# [1000 rows x 3 columns]

# %%
plt.plot(range(1000),df['one'],'r',df['two'],'g',df['three'])
# Out:
# [<matplotlib.lines.Line2D at 0x122771c39e8>,
#  <matplotlib.lines.Line2D at 0x122771c3ef0>,
#  <matplotlib.lines.Line2D at 0x122771c3eb8>]

# %%
df.head(5)
# Out:
#          one        two  three
# 0  24.844860  24.242688     16
# 1  25.495398  29.520541     17
# 2  29.854776  24.563702     19
# 3  29.318281  24.064152     17
# 4  27.859167  26.546887     16

# %%
df.tail(10)
# Out:
#            one        two  three
# 990  27.636181  24.260771     12
# 991  37.080736  22.633751     14
# 992  33.895452  28.840182     18
# 993  18.146541  27.449014     15
# 994  23.379142  24.874657     14
# 995  29.389368  26.318110     14
# 996  22.312277  27.612347     12
# 997  29.333433  24.293725     15
# 998  29.890832  23.086329     15
# 999  18.926483  26.349100     14

# %%
df1 = df.head(30)

# %%
plt.plot(range(30),df1['one'],'r',df1['two'],'g',df1['three'])
# Out:
# [<matplotlib.lines.Line2D at 0x122781fd898>,
#  <matplotlib.lines.Line2D at 0x122781fddd8>,
#  <matplotlib.lines.Line2D at 0x122781fdf28>]

# %%
df['one'].dtype
# Out:
# dtype('float64')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.columns
# Out:
# Index(['one', 'two', 'three'], dtype='object')

# %%
df.describe()
# Out:
#                one          two        three
# count  1000.000000  1000.000000  1000.000000
# mean     30.275787    24.924175    14.964000
# std       4.978415     2.459870     2.405929
# min      13.150052    16.881572     8.000000
# 25%      27.003924    23.197686    13.000000
# 50%      30.002131    24.900144    15.000000
# 75%      33.790584    26.639520    17.000000
# max      45.041335    32.801659    23.000000

# %%
df.T
# Out:
#              0          1          2          3          4          5    \
# one    24.844860  25.495398  29.854776  29.318281  27.859167  29.019029
# two    24.242688  29.520541  24.563702  24.064152  26.546887  27.682775
# three  16.000000  17.000000  19.000000  17.000000  16.000000  18.000000
#
#              6          7          8          9      ...            990  \
# one    27.901481  39.496588  31.810976  30.296350    ...      27.636181
# two    26.856199  23.005510  23.549107  18.931895    ...      24.260771
# three  14.000000  16.000000  13.000000  15.000000    ...      12.000000
#
#              991        992        993        994        995        996  \
# one    37.080736  33.895452  18.146541  23.379142  29.389368  22.312277
# two    22.633751  28.840182  27.449014  24.874657  26.318110  27.612347
# three  14.000000  18.000000  15.000000  14.000000  14.000000  12.000000
#
#              997        998        999
# one    29.333433  29.890832  18.926483
# two    24.293725  23.086329  26.349100
# three  15.000000  15.000000  14.000000
#
# [3 rows x 1000 columns]

# %%
from random import randint
df = pd.DataFrame(data=[[randint(5,50) for var in range(30)],[randint(5,50) for var in range(30)],[randint(5,50) for var in range(30)]])

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df = df.T

# %%
df
# Out:
#      0   1   2
# 0   23  21  43
# 1   25   5  41
# 2   19  13  22
# 3   33   7  14
# 4   14  17  48
# 5   50  50  27
# 6   28  35   7
# 7   29  11  36
# 8   11  33  28
# 9   38  13  46
# 10  27  46  28
# 11  16  49  48
# 12  20  30  49
# 13   9  44  48
# 14  10  14   7
# 15  43  42  15
# 16  36  37   9
# 17  28  17  21
# 18  44  44  30
# 19  19  31  26
# 20  12  30  13
# 21  39   9  32
# 22  39   8  32
# 23  38  10  39
# 24  37  23  18
# 25  34   6  27
# 26  46  27  32
# 27  48  34  13
# 28  50  28  15
# 29  12  32  24

# %%
df.columns = [ 'third','second','first']

# %%
df.index  = range(30,0,-1)

# %%
df
# Out:
#     third  second  first
# 30     23      21     43
# 29     25       5     41
# 28     19      13     22
# 27     33       7     14
# 26     14      17     48
# 25     50      50     27
# 24     28      35      7
# 23     29      11     36
# 22     11      33     28
# 21     38      13     46
# 20     27      46     28
# 19     16      49     48
# 18     20      30     49
# 17      9      44     48
# 16     10      14      7
# 15     43      42     15
# 14     36      37      9
# 13     28      17     21
# 12     44      44     30
# 11     19      31     26
# 10     12      30     13
# 9      39       9     32
# 8      39       8     32
# 7      38      10     39
# 6      37      23     18
# 5      34       6     27
# 4      46      27     32
# 3      48      34     13
# 2      50      28     15
# 1      12      32     24

# %%
df.sort_index(axis=0)
# Out:
#     third  second  first
# 1      12      32     24
# 2      50      28     15
# 3      48      34     13
# 4      46      27     32
# 5      34       6     27
# 6      37      23     18
# 7      38      10     39
# 8      39       8     32
# 9      39       9     32
# 10     12      30     13
# 11     19      31     26
# 12     44      44     30
# 13     28      17     21
# 14     36      37      9
# 15     43      42     15
# 16     10      14      7
# 17      9      44     48
# 18     20      30     49
# 19     16      49     48
# 20     27      46     28
# 21     38      13     46
# 22     11      33     28
# 23     29      11     36
# 24     28      35      7
# 25     50      50     27
# 26     14      17     48
# 27     33       7     14
# 28     19      13     22
# 29     25       5     41
# 30     23      21     43

# %%
df.sort_index(axis=1)
# Out:
#     first  second  third
# 30     43      21     23
# 29     41       5     25
# 28     22      13     19
# 27     14       7     33
# 26     48      17     14
# 25     27      50     50
# 24      7      35     28
# 23     36      11     29
# 22     28      33     11
# 21     46      13     38
# 20     28      46     27
# 19     48      49     16
# 18     49      30     20
# 17     48      44      9
# 16      7      14     10
# 15     15      42     43
# 14      9      37     36
# 13     21      17     28
# 12     30      44     44
# 11     26      31     19
# 10     13      30     12
# 9      32       9     39
# 8      32       8     39
# 7      39      10     38
# 6      18      23     37
# 5      27       6     34
# 4      32      27     46
# 3      13      34     48
# 2      15      28     50
# 1      24      32     12

# %%
df.sort_values(axis=0,by='second',ascending=False)
# Out:
#     third  second  first
# 25     50      50     27
# 19     16      49     48
# 20     27      46     28
# 12     44      44     30
# 17      9      44     48
# 15     43      42     15
# 14     36      37      9
# 24     28      35      7
# 3      48      34     13
# 22     11      33     28
# 1      12      32     24
# 11     19      31     26
# 10     12      30     13
# 18     20      30     49
# 2      50      28     15
# 4      46      27     32
# 6      37      23     18
# 30     23      21     43
# 13     28      17     21
# 26     14      17     48
# 16     10      14      7
# 28     19      13     22
# 21     38      13     46
# 23     29      11     36
# 7      38      10     39
# 9      39       9     32
# 8      39       8     32
# 27     33       7     14
# 5      34       6     27
# 29     25       5     41

# %%
plt.plot(df['second'],df['first'],'r',df['third'],'g')
# Out:
# [<matplotlib.lines.Line2D at 0x12278276d68>,
#  <matplotlib.lines.Line2D at 0x12278276eb8>]

# %%
df
# Out:
#     third  second  first
# 30     23      21     43
# 29     25       5     41
# 28     19      13     22
# 27     33       7     14
# 26     14      17     48
# 25     50      50     27
# 24     28      35      7
# 23     29      11     36
# 22     11      33     28
# 21     38      13     46
# 20     27      46     28
# 19     16      49     48
# 18     20      30     49
# 17      9      44     48
# 16     10      14      7
# 15     43      42     15
# 14     36      37      9
# 13     28      17     21
# 12     44      44     30
# 11     19      31     26
# 10     12      30     13
# 9      39       9     32
# 8      39       8     32
# 7      38      10     39
# 6      37      23     18
# 5      34       6     27
# 4      46      27     32
# 3      48      34     13
# 2      50      28     15
# 1      12      32     24

# %%
df.index = range(30)
df = df.sort_index(axis=0)
print(df)
# Out:
#     third  second  first
# 0      23      21     43
# 1      25       5     41
# 2      19      13     22
# 3      33       7     14
# 4      14      17     48
# 5      50      50     27
# 6      28      35      7
# 7      29      11     36
# 8      11      33     28
# 9      38      13     46
# 10     27      46     28
# 11     16      49     48
# 12     20      30     49
# 13      9      44     48
# 14     10      14      7
# 15     43      42     15
# 16     36      37      9
# 17     28      17     21
# 18     44      44     30
# 19     19      31     26
# 20     12      30     13
# 21     39       9     32
# 22     39       8     32
# 23     38      10     39
# 24     37      23     18
# 25     34       6     27
# 26     46      27     32
# 27     48      34     13
# 28     50      28     15
# 29     12      32     24

# %%
df[5:25:3]
# Out:
#     third  second  first
# 5      50      50     27
# 8      11      33     28
# 11     16      49     48
# 14     10      14      7
# 17     28      17     21
# 20     12      30     13
# 23     38      10     39

# %%
df.index = pd.date_range('20181110',periods=30)

# %%
df.sort_index(axis=0,ascending=False).sort_index(axis=1)[:5].describe()
# Out:
#            first    second      third
# count   5.000000   5.00000   5.000000
# mean   22.200000  25.40000  38.000000
# std     8.043631  11.21606  15.811388
# min    13.000000   6.00000  12.000000
# 25%    15.000000  27.00000  34.000000
# 50%    24.000000  28.00000  46.000000
# 75%    27.000000  32.00000  48.000000
# max    32.000000  34.00000  50.000000

# %%
df
# Out:
#             third  second  first
# 2018-11-10     23      21     43
# 2018-11-11     25       5     41
# 2018-11-12     19      13     22
# 2018-11-13     33       7     14
# 2018-11-14     14      17     48
# 2018-11-15     50      50     27
# 2018-11-16     28      35      7
# 2018-11-17     29      11     36
# 2018-11-18     11      33     28
# 2018-11-19     38      13     46
# 2018-11-20     27      46     28
# 2018-11-21     16      49     48
# 2018-11-22     20      30     49
# 2018-11-23      9      44     48
# 2018-11-24     10      14      7
# 2018-11-25     43      42     15
# 2018-11-26     36      37      9
# 2018-11-27     28      17     21
# 2018-11-28     44      44     30
# 2018-11-29     19      31     26
# 2018-11-30     12      30     13
# 2018-12-01     39       9     32
# 2018-12-02     39       8     32
# 2018-12-03     38      10     39
# 2018-12-04     37      23     18
# 2018-12-05     34       6     27
# 2018-12-06     46      27     32
# 2018-12-07     48      34     13
# 2018-12-08     50      28     15
# 2018-12-09     12      32     24

# %%
df[::5]
# Out:
#             third  second  first
# 2018-11-10     23      21     43
# 2018-11-15     50      50     27
# 2018-11-20     27      46     28
# 2018-11-25     43      42     15
# 2018-11-30     12      30     13
# 2018-12-05     34       6     27

# %%
df['20181110':'20181120']
# Out:
#             third  second  first
# 2018-11-10     23      21     43
# 2018-11-11     25       5     41
# 2018-11-12     19      13     22
# 2018-11-13     33       7     14
# 2018-11-14     14      17     48
# 2018-11-15     50      50     27
# 2018-11-16     28      35      7
# 2018-11-17     29      11     36
# 2018-11-18     11      33     28
# 2018-11-19     38      13     46
# 2018-11-20     27      46     28

# %%
df = pd.read_csv('StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
mf = pd.value_counts(df['gender'])

# %%
mf
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
mf.dtype
# Out:
# dtype('int64')

# %%
male = mf[1]
female = mf[0]

# %%
total = male+female

# %%
male_per = round(( mf[1] / total ) * 100,3)

# %%
female_per  = round(( mf[0] / total ) * 100,3)

# %%
print(f"Male Percentage = {male_per} and Female Percentage = {female_per} ")
# Out:
# Male Percentage = 48.2 and Female Percentage = 51.8

# %%
print(df.columns)
type_of_degree = df['race/ethnicity'].unique()
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
print(type_of_degree)
# Out:
# ['group B' 'group C' 'group A' 'group D' 'group E']

# %%
type_of_degree = pd.value_counts(df['race/ethnicity'])

# %%
t = sum(type_of_degree)
t
# Out:
# 1000

# %%
type_of_degree
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
group = [ 'A','B','C','D','E']
loc = [ 4,2,0,1,3]
per = []
for index in loc : 
    per.append(round((type_of_degree[index]/10),3))
print(*zip(group,per))
# Out:
# ('A', 8.9) ('B', 19.0) ('C', 31.9) ('D', 26.2) ('E', 14.0)

# %%
import matplotlib.pyplot as plt 

plt.pie(per,labels=group,autopct='%.2f',radius=1.2,shadow=True,labeldistance=0.9,startangle=90,center=(5,1),counterclock=False,wedgeprops = {'linewidth': 30},)
plt.show()

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df[['gender','math score','writing score']][1:10]
# Out:
#    gender  math score  writing score
# 1  female          69             88
# 2  female          90             93
# 3    male          47             44
# 4    male          76             75
# 5  female          71             78
# 6  female          88             92
# 7    male          40             39
# 8    male          64             67
# 9  female          38             50

# %%
df.loc[[1,5,100]]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 1    female        group C                some college  standard
# 5    female        group B          associate's degree  standard
# 100    male        group B                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 1                 completed          69             90             88
# 5                      none          71             83             78
# 100                    none          79             67             67

# %%
df.loc[25:50,['gender','math score']]
# Out:
#     gender  math score
# 25    male          73
# 26    male          69
# 27  female          67
# 28    male          70
# 29  female          62
# 30  female          69
# 31  female          63
# 32  female          56
# 33    male          40
# 34    male          97
# 35    male          81
# 36  female          74
# 37  female          50
# 38  female          75
# 39    male          57
# 40    male          55
# 41  female          58
# 42  female          53
# 43    male          59
# 44  female          50
# 45    male          65
# 46  female          55
# 47  female          66
# 48  female          57
# 49    male          82
# 50    male          53

# %%
df.loc[5,'gender']
# Out:
# 'female'

# %%
df.at[7,'gender']
# Out:
# 'male'

# %%
dates = pd.date_range('20180101',periods=1000)

# %%
df.index = dates

# %%
df
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# 2018-01-01  female        group B           bachelor's degree      standard
# 2018-01-02  female        group C                some college      standard
# 2018-01-03  female        group B             master's degree      standard
# 2018-01-04    male        group A          associate's degree  free/reduced
# 2018-01-05    male        group C                some college      standard
# 2018-01-06  female        group B          associate's degree      standard
# 2018-01-07  female        group B                some college      standard
# 2018-01-08    male        group B                some college  free/reduced
# 2018-01-09    male        group D                 high school  free/reduced
# 2018-01-10  female        group B                 high school  free/reduced
# 2018-01-11    male        group C          associate's degree      standard
# 2018-01-12    male        group D          associate's degree      standard
# 2018-01-13  female        group B                 high school      standard
# 2018-01-14    male        group A                some college      standard
# 2018-01-15  female        group A             master's degree      standard
# 2018-01-16  female        group C            some high school      standard
# 2018-01-17    male        group C                 high school      standard
# 2018-01-18  female        group B            some high school  free/reduced
# 2018-01-19    male        group C             master's degree  free/reduced
# 2018-01-20  female        group C          associate's degree  free/reduced
# 2018-01-21    male        group D                 high school      standard
# 2018-01-22  female        group B                some college  free/reduced
# 2018-01-23    male        group D                some college      standard
# 2018-01-24  female        group C            some high school      standard
# 2018-01-25    male        group D           bachelor's degree  free/reduced
# 2018-01-26    male        group A             master's degree  free/reduced
# 2018-01-27    male        group B                some college      standard
# 2018-01-28  female        group C           bachelor's degree      standard
# 2018-01-29    male        group C                 high school      standard
# 2018-01-30  female        group D             master's degree      standard
# ...            ...            ...                         ...           ...
# 2020-08-28  female        group D           bachelor's degree      standard
# 2020-08-29    male        group C            some high school      standard
# 2020-08-30  female        group A                 high school  free/reduced
# 2020-08-31  female        group D                some college  free/reduced
# 2020-09-01  female        group A                some college      standard
# 2020-09-02  female        group C                some college      standard
# 2020-09-03    male        group B                some college  free/reduced
# 2020-09-04    male        group C          associate's degree      standard
# 2020-09-05    male        group D                 high school      standard
# 2020-09-06  female        group C          associate's degree      standard
# 2020-09-07  female        group B                 high school  free/reduced
# 2020-09-08    male        group D            some high school      standard
# 2020-09-09    male        group B            some high school      standard
# 2020-09-10  female        group A                some college      standard
# 2020-09-11  female        group C            some high school      standard
# 2020-09-12    male        group A                 high school      standard
# 2020-09-13  female        group C          associate's degree      standard
# 2020-09-14    male        group E            some high school      standard
# 2020-09-15  female        group A            some high school  free/reduced
# 2020-09-16  female        group D                some college  free/reduced
# 2020-09-17    male        group E                 high school  free/reduced
# 2020-09-18  female        group B            some high school      standard
# 2020-09-19  female        group D          associate's degree  free/reduced
# 2020-09-20  female        group D           bachelor's degree  free/reduced
# 2020-09-21    male        group A                 high school      standard
# 2020-09-22  female        group E             master's degree      standard
# 2020-09-23    male        group C                 high school  free/reduced
# 2020-09-24  female        group C                 high school  free/reduced
# 2020-09-25  female        group D                some college      standard
# 2020-09-26  female        group D                some college  free/reduced
#
#            test preparation course  math score  reading score  writing score
# 2018-01-01                    none          72             72             74
# 2018-01-02               completed          69             90             88
# 2018-01-03                    none          90             95             93
# 2018-01-04                    none          47             57             44
# 2018-01-05                    none          76             78             75
# 2018-01-06                    none          71             83             78
# 2018-01-07               completed          88             95             92
# 2018-01-08                    none          40             43             39
# 2018-01-09               completed          64             64             67
# 2018-01-10                    none          38             60             50
# 2018-01-11                    none          58             54             52
# 2018-01-12                    none          40             52             43
# 2018-01-13                    none          65             81             73
# 2018-01-14               completed          78             72             70
# 2018-01-15                    none          50             53             58
# 2018-01-16                    none          69             75             78
# 2018-01-17                    none          88             89             86
# 2018-01-18                    none          18             32             28
# 2018-01-19               completed          46             42             46
# 2018-01-20                    none          54             58             61
# 2018-01-21                    none          66             69             63
# 2018-01-22               completed          65             75             70
# 2018-01-23                    none          44             54             53
# 2018-01-24                    none          69             73             73
# 2018-01-25               completed          74             71             80
# 2018-01-26                    none          73             74             72
# 2018-01-27                    none          69             54             55
# 2018-01-28                    none          67             69             75
# 2018-01-29                    none          70             70             65
# 2018-01-30                    none          62             70             75
# ...                            ...         ...            ...            ...
# 2020-08-28                    none          89            100            100
# 2020-08-29               completed          78             72             69
# 2020-08-30               completed          53             50             60
# 2020-08-31                    none          49             65             61
# 2020-09-01                    none          54             63             67
# 2020-09-02               completed          64             82             77
# 2020-09-03               completed          60             62             60
# 2020-09-04                    none          62             65             58
# 2020-09-05               completed          55             41             48
# 2020-09-06                    none          91             95             94
# 2020-09-07                    none           8             24             23
# 2020-09-08                    none          81             78             78
# 2020-09-09               completed          79             85             86
# 2020-09-10               completed          78             87             91
# 2020-09-11                    none          74             75             82
# 2020-09-12                    none          57             51             54
# 2020-09-13                    none          40             59             51
# 2020-09-14               completed          81             75             76
# 2020-09-15                    none          44             45             45
# 2020-09-16               completed          67             86             83
# 2020-09-17               completed          86             81             75
# 2020-09-18               completed          65             82             78
# 2020-09-19                    none          55             76             76
# 2020-09-20                    none          62             72             74
# 2020-09-21                    none          63             63             62
# 2020-09-22               completed          88             99             95
# 2020-09-23                    none          62             55             55
# 2020-09-24               completed          59             71             65
# 2020-09-25               completed          68             78             77
# 2020-09-26                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
df.loc['20180715','math score']
# Out:
# 61

# %%
df.loc['20180715':'20180730',['gender','writing score']]
# Out:
#             gender  writing score
# 2018-07-15    male             52
# 2018-07-16    male             65
# 2018-07-17    male             51
# 2018-07-18  female             55
# 2018-07-19  female             76
# 2018-07-20  female             86
# 2018-07-21  female             77
# 2018-07-22    male             69
# 2018-07-23  female             68
# 2018-07-24    male             42
# 2018-07-25    male             78
# 2018-07-26    male             62
# 2018-07-27    male             76
# 2018-07-28  female             76
# 2018-07-29  female             66
# 2018-07-30    male             79

# %%
df.iloc[450:500,[0,3,5]]
# Out:
#             gender         lunch  math score
# 2019-03-27  female  free/reduced          64
# 2019-03-28  female      standard         100
# 2019-03-29  female  free/reduced          65
# 2019-03-30    male  free/reduced          65
# 2019-03-31  female  free/reduced          53
# 2019-04-01    male  free/reduced          37
# 2019-04-02  female      standard          79
# 2019-04-03    male  free/reduced          53
# 2019-04-04  female      standard         100
# 2019-04-05    male      standard          72
# 2019-04-06    male  free/reduced          53
# 2019-04-07    male  free/reduced          54
# 2019-04-08  female      standard          71
# 2019-04-09  female  free/reduced          77
# 2019-04-10    male      standard          75
# 2019-04-11  female      standard          84
# 2019-04-12  female  free/reduced          26
# 2019-04-13    male  free/reduced          72
# 2019-04-14  female  free/reduced          77
# 2019-04-15    male      standard          91
# 2019-04-16  female      standard          83
# 2019-04-17  female      standard          63
# 2019-04-18  female      standard          68
# 2019-04-19  female      standard          59
# 2019-04-20  female      standard          90
# 2019-04-21  female      standard          71
# 2019-04-22    male      standard          76
# 2019-04-23    male      standard          80
# 2019-04-24  female      standard          55
# 2019-04-25    male      standard          76
# 2019-04-26    male      standard          73
# 2019-04-27  female  free/reduced          52
# 2019-04-28    male  free/reduced          68
# 2019-04-29    male      standard          59
# 2019-04-30  female      standard          49
# 2019-05-01    male      standard          70
# 2019-05-02    male  free/reduced          61
# 2019-05-03  female  free/reduced          60
# 2019-05-04    male      standard          64
# 2019-05-05    male  free/reduced          79
# 2019-05-06  female  free/reduced          65
# 2019-05-07  female      standard          64
# 2019-05-08  female      standard          83
# 2019-05-09  female      standard          81
# 2019-05-10  female      standard          54
# 2019-05-11    male      standard          68
# 2019-05-12  female      standard          54
# 2019-05-13  female  free/reduced          59
# 2019-05-14  female      standard          66
# 2019-05-15    male      standard          76

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.columns = [ 'gender','type','degree','lunch','course','math','rscore','wscore']

# %%
df.columns
# Out:
# Index(['gender', 'type', 'degree', 'lunch', 'course', 'math', 'rscore',
#        'wscore'],
#       dtype='object')

# %%
df[:5]
# Out:
#             gender     type              degree         lunch     course  \
# 2018-01-01  female  group B   bachelor's degree      standard       none
# 2018-01-02  female  group C        some college      standard  completed
# 2018-01-03  female  group B     master's degree      standard       none
# 2018-01-04    male  group A  associate's degree  free/reduced       none
# 2018-01-05    male  group C        some college      standard       none
#
#             math  rscore  wscore
# 2018-01-01    72      72      74
# 2018-01-02    69      90      88
# 2018-01-03    90      95      93
# 2018-01-04    47      57      44
# 2018-01-05    76      78      75

# %%
df.iloc[:25,[0,5,6,7]][df.math > 75]
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             gender  math  rscore  wscore
# 2018-01-03  female    90      95      93
# 2018-01-05    male    76      78      75
# 2018-01-07  female    88      95      92
# 2018-01-14    male    78      72      70
# 2018-01-17    male    88      89      86

# %%
df.iloc[:6,[0,5,6,7]][df.math>60]
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             gender  math  rscore  wscore
# 2018-01-01  female    72      72      74
# 2018-01-02  female    69      90      88
# 2018-01-03  female    90      95      93
# 2018-01-05    male    76      78      75
# 2018-01-06  female    71      83      78

# %%
df[df.degree.isin(['bachelor\'s degree'])]
# Out:
#             gender     type             degree         lunch     course  math  \
# 2018-01-01  female  group B  bachelor's degree      standard       none    72
# 2018-01-25    male  group D  bachelor's degree  free/reduced  completed    74
# 2018-01-28  female  group C  bachelor's degree      standard       none    67
# 2018-03-02    male  group E  bachelor's degree  free/reduced  completed    79
# 2018-03-19    male  group A  bachelor's degree      standard  completed    80
# 2018-04-01  female  group C  bachelor's degree      standard       none    65
# 2018-04-10  female  group D  bachelor's degree      standard       none    65
# 2018-04-12    male  group D  bachelor's degree      standard  completed    68
# 2018-04-25  female  group E  bachelor's degree      standard  completed    99
# 2018-04-27  female  group B  bachelor's degree  free/reduced       none    75
# 2018-04-28  female  group D  bachelor's degree      standard       none    78
# 2018-05-01  female  group C  bachelor's degree      standard  completed    79
# 2018-05-10  female  group A  bachelor's degree      standard       none    51
# 2018-05-15    male  group D  bachelor's degree  free/reduced  completed    74
# 2018-05-16    male  group C  bachelor's degree      standard       none    58
# 2018-05-29  female  group D  bachelor's degree      standard  completed    68
# 2018-06-01    male  group A  bachelor's degree      standard       none    77
# 2018-06-03    male  group D  bachelor's degree      standard       none    54
# 2018-06-15  female  group C  bachelor's degree      standard  completed    96
# 2018-06-24  female  group C  bachelor's degree  free/reduced  completed    43
# 2018-07-09  female  group C  bachelor's degree      standard       none    77
# 2018-07-19  female  group B  bachelor's degree  free/reduced       none    78
# 2018-07-26    male  group E  bachelor's degree      standard       none    82
# 2018-08-21  female  group B  bachelor's degree      standard       none    67
# 2018-08-23    male  group C  bachelor's degree      standard  completed    83
# 2018-08-25    male  group D  bachelor's degree  free/reduced       none    63
# 2018-08-30  female  group E  bachelor's degree      standard       none    80
# 2018-09-24  female  group C  bachelor's degree      standard       none    63
# 2018-09-28    male  group C  bachelor's degree      standard       none    69
# 2018-10-03    male  group C  bachelor's degree      standard       none    83
# ...            ...      ...                ...           ...        ...   ...
# 2020-01-11    male  group D  bachelor's degree      standard       none    80
# 2020-01-19  female  group C  bachelor's degree  free/reduced       none    50
# 2020-01-28    male  group E  bachelor's degree  free/reduced  completed    70
# 2020-02-11    male  group D  bachelor's degree      standard       none    75
# 2020-02-13  female  group C  bachelor's degree  free/reduced       none    62
# 2020-02-24    male  group C  bachelor's degree      standard  completed    91
# 2020-03-20    male  group B  bachelor's degree      standard       none    59
# 2020-03-27  female  group A  bachelor's degree      standard       none    45
# 2020-03-28    male  group D  bachelor's degree  free/reduced  completed    61
# 2020-04-01  female  group D  bachelor's degree  free/reduced       none    78
# 2020-04-11  female  group C  bachelor's degree  free/reduced  completed    74
# 2020-04-12    male  group A  bachelor's degree      standard       none    64
# 2020-05-05  female  group B  bachelor's degree      standard       none    97
# 2020-05-07  female  group C  bachelor's degree      standard       none    65
# 2020-05-12    male  group D  bachelor's degree  free/reduced  completed    39
# 2020-05-24  female  group C  bachelor's degree  free/reduced       none    43
# 2020-05-30    male  group C  bachelor's degree      standard  completed    63
# 2020-05-31  female  group E  bachelor's degree      standard  completed    71
# 2020-06-02    male  group D  bachelor's degree  free/reduced       none    55
# 2020-06-22  female  group D  bachelor's degree  free/reduced  completed    93
# 2020-06-27  female  group C  bachelor's degree  free/reduced       none    67
# 2020-06-28    male  group E  bachelor's degree      standard  completed    70
# 2020-06-29    male  group D  bachelor's degree  free/reduced       none    50
# 2020-07-01  female  group C  bachelor's degree      standard  completed    52
# 2020-07-02  female  group C  bachelor's degree  free/reduced  completed    47
# 2020-07-05    male  group E  bachelor's degree      standard  completed   100
# 2020-07-22    male  group C  bachelor's degree  free/reduced  completed    70
# 2020-08-27  female  group B  bachelor's degree      standard       none    75
# 2020-08-28  female  group D  bachelor's degree      standard       none    89
# 2020-09-20  female  group D  bachelor's degree  free/reduced       none    62
#
#             rscore  wscore
# 2018-01-01      72      74
# 2018-01-25      71      80
# 2018-01-28      69      75
# 2018-03-02      74      72
# 2018-03-19      78      81
# 2018-04-01      72      74
# 2018-04-10      67      62
# 2018-04-12      74      74
# 2018-04-25     100     100
# 2018-04-27      85      82
# 2018-04-28      82      79
# 2018-05-01      92      89
# 2018-05-10      49      51
# 2018-05-15      79      75
# 2018-05-16      55      48
# 2018-05-29      75      81
# 2018-06-01      67      68
# 2018-06-03      49      47
# 2018-06-15     100     100
# 2018-06-24      51      54
# 2018-07-09      88      87
# 2018-07-19      79      76
# 2018-07-26      62      62
# 2018-08-21      86      83
# 2018-08-23      82      84
# 2018-08-25      66      67
# 2018-08-30      83      83
# 2018-09-24      75      81
# 2018-09-28      63      61
# 2018-10-03      78      73
# ...            ...     ...
# 2020-01-11      73      72
# 2020-01-19      60      59
# 2020-01-28      68      72
# 2020-02-11      73      74
# 2020-02-13      78      79
# 2020-02-24      81      79
# 2020-03-20      54      51
# 2020-03-27      59      64
# 2020-03-28      70      76
# 2020-04-01      90      93
# 2020-04-11      86      89
# 2020-04-12      60      58
# 2020-05-05      97      96
# 2020-05-07      79      81
# 2020-05-12      42      38
# 2020-05-24      62      61
# 2020-05-30      64      66
# 2020-05-31      70      70
# 2020-06-02      46      44
# 2020-06-22     100     100
# 2020-06-27      75      72
# 2020-06-28      64      70
# 2020-06-29      42      48
# 2020-07-01      61      66
# 2020-07-02      62      66
# 2020-07-05     100     100
# 2020-07-22      75      74
# 2020-08-27      84      80
# 2020-08-28     100     100
# 2020-09-20      72      74
#
# [118 rows x 8 columns]

# %%
df['degree'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
import random 
vscore = [ random.randint(50,100) for var in range(1000)]

# %%
df['vscore'] = vscore

# %%
df.columns
# Out:
# Index(['gender', 'type', 'degree', 'lunch', 'course', 'math', 'rscore',
#        'wscore', 'vscore'],
#       dtype='object')

# %%
df.head()
# Out:
#             gender     type              degree         lunch     course  \
# 2018-01-01  female  group B   bachelor's degree      standard       none
# 2018-01-02  female  group C        some college      standard  completed
# 2018-01-03  female  group B     master's degree      standard       none
# 2018-01-04    male  group A  associate's degree  free/reduced       none
# 2018-01-05    male  group C        some college      standard       none
#
#             math  rscore  wscore  vscore
# 2018-01-01    72      72      74      79
# 2018-01-02    69      90      88      51
# 2018-01-03    90      95      93      68
# 2018-01-04    47      57      44      68
# 2018-01-05    76      78      75      65

# %%
del df['vscore']

# %%
del df['type']

# %%
del df['lunch']

# %%
df.course[df.course.isin(['none'])] = 'Reading'
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#      gender              degree     course  math  rscore  wscore
# 0    female   bachelor's degree    Reading    72      72      74
# 1    female        some college  completed    69      90      88
# 2    female     master's degree    Reading    90      95      93
# 3      male  associate's degree    Reading    47      57      44
# 4      male        some college    Reading    76      78      75
# 5    female  associate's degree    Reading    71      83      78
# 6    female        some college  completed    88      95      92
# 7      male        some college    Reading    40      43      39
# 8      male         high school  completed    64      64      67
# 9    female         high school    Reading    38      60      50
# 10     male  associate's degree    Reading    58      54      52
# 11     male  associate's degree    Reading    40      52      43
# 12   female         high school    Reading    65      81      73
# 13     male        some college  completed    78      72      70
# 14   female     master's degree    Reading    50      53      58
# 15   female    some high school    Reading    69      75      78
# 16     male         high school    Reading    88      89      86
# 17   female    some high school    Reading    18      32      28
# 18     male     master's degree  completed    46      42      46
# 19   female  associate's degree    Reading    54      58      61
# 20     male         high school    Reading    66      69      63
# 21   female        some college  completed    65      75      70
# 22     male        some college    Reading    44      54      53
# 23   female    some high school    Reading    69      73      73
# 24     male   bachelor's degree  completed    74      71      80
# 25     male     master's degree    Reading    73      74      72
# 26     male        some college    Reading    69      54      55
# 27   female   bachelor's degree    Reading    67      69      75
# 28     male         high school    Reading    70      70      65
# 29   female     master's degree    Reading    62      70      75
# ..      ...                 ...        ...   ...     ...     ...
# 970  female   bachelor's degree    Reading    89     100     100
# 971    male    some high school  completed    78      72      69
# 972  female         high school  completed    53      50      60
# 973  female        some college    Reading    49      65      61
# 974  female        some college    Reading    54      63      67
# 975  female        some college  completed    64      82      77
# 976    male        some college  completed    60      62      60
# 977    male  associate's degree    Reading    62      65      58
# 978    male         high school  completed    55      41      48
# 979  female  associate's degree    Reading    91      95      94
# 980  female         high school    Reading     8      24      23
# 981    male    some high school    Reading    81      78      78
# 982    male    some high school  completed    79      85      86
# 983  female        some college  completed    78      87      91
# 984  female    some high school    Reading    74      75      82
# 985    male         high school    Reading    57      51      54
# 986  female  associate's degree    Reading    40      59      51
# 987    male    some high school  completed    81      75      76
# 988  female    some high school    Reading    44      45      45
# 989  female        some college  completed    67      86      83
# 990    male         high school  completed    86      81      75
# 991  female    some high school  completed    65      82      78
# 992  female  associate's degree    Reading    55      76      76
# 993  female   bachelor's degree    Reading    62      72      74
# 994    male         high school    Reading    63      63      62
# 995  female     master's degree  completed    88      99      95
# 996    male         high school    Reading    62      55      55
# 997  female         high school  completed    59      71      65
# 998  female        some college  completed    68      78      77
# 999  female        some college    Reading    77      86      86
#
# [1000 rows x 6 columns]

# %%
import numpy as np

# %%
df.course[df.course.isin(['Reading'])] = np.nan
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#      gender              degree     course  math  rscore  wscore
# 0    female   bachelor's degree        NaN    72      72      74
# 1    female        some college  completed    69      90      88
# 2    female     master's degree        NaN    90      95      93
# 3      male  associate's degree        NaN    47      57      44
# 4      male        some college        NaN    76      78      75
# 5    female  associate's degree        NaN    71      83      78
# 6    female        some college  completed    88      95      92
# 7      male        some college        NaN    40      43      39
# 8      male         high school  completed    64      64      67
# 9    female         high school        NaN    38      60      50
# 10     male  associate's degree        NaN    58      54      52
# 11     male  associate's degree        NaN    40      52      43
# 12   female         high school        NaN    65      81      73
# 13     male        some college  completed    78      72      70
# 14   female     master's degree        NaN    50      53      58
# 15   female    some high school        NaN    69      75      78
# 16     male         high school        NaN    88      89      86
# 17   female    some high school        NaN    18      32      28
# 18     male     master's degree  completed    46      42      46
# 19   female  associate's degree        NaN    54      58      61
# 20     male         high school        NaN    66      69      63
# 21   female        some college  completed    65      75      70
# 22     male        some college        NaN    44      54      53
# 23   female    some high school        NaN    69      73      73
# 24     male   bachelor's degree  completed    74      71      80
# 25     male     master's degree        NaN    73      74      72
# 26     male        some college        NaN    69      54      55
# 27   female   bachelor's degree        NaN    67      69      75
# 28     male         high school        NaN    70      70      65
# 29   female     master's degree        NaN    62      70      75
# ..      ...                 ...        ...   ...     ...     ...
# 970  female   bachelor's degree        NaN    89     100     100
# 971    male    some high school  completed    78      72      69
# 972  female         high school  completed    53      50      60
# 973  female        some college        NaN    49      65      61
# 974  female        some college        NaN    54      63      67
# 975  female        some college  completed    64      82      77
# 976    male        some college  completed    60      62      60
# 977    male  associate's degree        NaN    62      65      58
# 978    male         high school  completed    55      41      48
# 979  female  associate's degree        NaN    91      95      94
# 980  female         high school        NaN     8      24      23
# 981    male    some high school        NaN    81      78      78
# 982    male    some high school  completed    79      85      86
# 983  female        some college  completed    78      87      91
# 984  female    some high school        NaN    74      75      82
# 985    male         high school        NaN    57      51      54
# 986  female  associate's degree        NaN    40      59      51
# 987    male    some high school  completed    81      75      76
# 988  female    some high school        NaN    44      45      45
# 989  female        some college  completed    67      86      83
# 990    male         high school  completed    86      81      75
# 991  female    some high school  completed    65      82      78
# 992  female  associate's degree        NaN    55      76      76
# 993  female   bachelor's degree        NaN    62      72      74
# 994    male         high school        NaN    63      63      62
# 995  female     master's degree  completed    88      99      95
# 996    male         high school        NaN    62      55      55
# 997  female         high school  completed    59      71      65
# 998  female        some college  completed    68      78      77
# 999  female        some college        NaN    77      86      86
#
# [1000 rows x 6 columns]

# %%
df1 = df.copy()

# %%
df.dropna?

# %%
all([True,True,True])
# Out:
# True

# %%
df2 = df.dropna(how='any')

# %%
df2
# Out:
#      gender              degree     course  math  rscore  wscore
# 1    female        some college  completed    69      90      88
# 6    female        some college  completed    88      95      92
# 8      male         high school  completed    64      64      67
# 13     male        some college  completed    78      72      70
# 18     male     master's degree  completed    46      42      46
# 21   female        some college  completed    65      75      70
# 24     male   bachelor's degree  completed    74      71      80
# 35     male  associate's degree  completed    81      81      79
# 38   female  associate's degree  completed    75      90      88
# 43     male        some college  completed    59      65      66
# 46   female  associate's degree  completed    55      65      62
# 48   female  associate's degree  completed    57      74      76
# 49     male         high school  completed    82      84      82
# 51     male  associate's degree  completed    77      69      68
# 54   female    some high school  completed    71      84      87
# 56   female  associate's degree  completed    82      85      86
# 58     male        some college  completed    58      59      58
# 60     male   bachelor's degree  completed    79      74      72
# 70   female        some college  completed    58      63      73
# 71     male        some college  completed    63      55      63
# 77     male   bachelor's degree  completed    80      78      81
# 78   female    some high school  completed    61      74      72
# 82     male        some college  completed    50      47      54
# 93     male  associate's degree  completed    43      45      50
# 95     male  associate's degree  completed    78      81      82
# 96     male    some high school  completed    65      66      62
# 97   female        some college  completed    63      72      70
# 101    male   bachelor's degree  completed    68      74      74
# 103    male         high school  completed    60      44      47
# 104    male        some college  completed    98      86      90
# ..      ...                 ...        ...   ...     ...     ...
# 927  female         high school  completed    65      61      71
# 928    male  associate's degree  completed    46      43      44
# 930    male        some college  completed    67      74      70
# 932    male  associate's degree  completed    61      71      73
# 933    male   bachelor's degree  completed    70      75      74
# 934    male  associate's degree  completed    98      87      90
# 938    male        some college  completed    85      81      85
# 939    male    some high school  completed    77      68      69
# 940    male     master's degree  completed    72      66      72
# 943    male    some high school  completed    61      62      61
# 948    male    some high school  completed    49      50      52
# 949  female         high school  completed    57      75      73
# 951  female        some college  completed    75      77      83
# 953    male         high school  completed    58      52      54
# 963  female    some high school  completed    65      76      75
# 966    male    some high school  completed    66      68      64
# 971    male    some high school  completed    78      72      69
# 972  female         high school  completed    53      50      60
# 975  female        some college  completed    64      82      77
# 976    male        some college  completed    60      62      60
# 978    male         high school  completed    55      41      48
# 982    male    some high school  completed    79      85      86
# 983  female        some college  completed    78      87      91
# 987    male    some high school  completed    81      75      76
# 989  female        some college  completed    67      86      83
# 990    male         high school  completed    86      81      75
# 991  female    some high school  completed    65      82      78
# 995  female     master's degree  completed    88      99      95
# 997  female         high school  completed    59      71      65
# 998  female        some college  completed    68      78      77
#
# [358 rows x 6 columns]

# %%
df
# Out:
#      gender              degree     course  math  rscore  wscore
# 0    female   bachelor's degree        NaN    72      72      74
# 1    female        some college  completed    69      90      88
# 2    female     master's degree        NaN    90      95      93
# 3      male  associate's degree        NaN    47      57      44
# 4      male        some college        NaN    76      78      75
# 5    female  associate's degree        NaN    71      83      78
# 6    female        some college  completed    88      95      92
# 7      male        some college        NaN    40      43      39
# 8      male         high school  completed    64      64      67
# 9    female         high school        NaN    38      60      50
# 10     male  associate's degree        NaN    58      54      52
# 11     male  associate's degree        NaN    40      52      43
# 12   female         high school        NaN    65      81      73
# 13     male        some college  completed    78      72      70
# 14   female     master's degree        NaN    50      53      58
# 15   female    some high school        NaN    69      75      78
# 16     male         high school        NaN    88      89      86
# 17   female    some high school        NaN    18      32      28
# 18     male     master's degree  completed    46      42      46
# 19   female  associate's degree        NaN    54      58      61
# 20     male         high school        NaN    66      69      63
# 21   female        some college  completed    65      75      70
# 22     male        some college        NaN    44      54      53
# 23   female    some high school        NaN    69      73      73
# 24     male   bachelor's degree  completed    74      71      80
# 25     male     master's degree        NaN    73      74      72
# 26     male        some college        NaN    69      54      55
# 27   female   bachelor's degree        NaN    67      69      75
# 28     male         high school        NaN    70      70      65
# 29   female     master's degree        NaN    62      70      75
# ..      ...                 ...        ...   ...     ...     ...
# 970  female   bachelor's degree        NaN    89     100     100
# 971    male    some high school  completed    78      72      69
# 972  female         high school  completed    53      50      60
# 973  female        some college        NaN    49      65      61
# 974  female        some college        NaN    54      63      67
# 975  female        some college  completed    64      82      77
# 976    male        some college  completed    60      62      60
# 977    male  associate's degree        NaN    62      65      58
# 978    male         high school  completed    55      41      48
# 979  female  associate's degree        NaN    91      95      94
# 980  female         high school        NaN     8      24      23
# 981    male    some high school        NaN    81      78      78
# 982    male    some high school  completed    79      85      86
# 983  female        some college  completed    78      87      91
# 984  female    some high school        NaN    74      75      82
# 985    male         high school        NaN    57      51      54
# 986  female  associate's degree        NaN    40      59      51
# 987    male    some high school  completed    81      75      76
# 988  female    some high school        NaN    44      45      45
# 989  female        some college  completed    67      86      83
# 990    male         high school  completed    86      81      75
# 991  female    some high school  completed    65      82      78
# 992  female  associate's degree        NaN    55      76      76
# 993  female   bachelor's degree        NaN    62      72      74
# 994    male         high school        NaN    63      63      62
# 995  female     master's degree  completed    88      99      95
# 996    male         high school        NaN    62      55      55
# 997  female         high school  completed    59      71      65
# 998  female        some college  completed    68      78      77
# 999  female        some college        NaN    77      86      86
#
# [1000 rows x 6 columns]

# %%
df.fillna('reading')
# Out:
#      gender              degree     course  math  rscore  wscore
# 0    female   bachelor's degree    reading    72      72      74
# 1    female        some college  completed    69      90      88
# 2    female     master's degree    reading    90      95      93
# 3      male  associate's degree    reading    47      57      44
# 4      male        some college    reading    76      78      75
# 5    female  associate's degree    reading    71      83      78
# 6    female        some college  completed    88      95      92
# 7      male        some college    reading    40      43      39
# 8      male         high school  completed    64      64      67
# 9    female         high school    reading    38      60      50
# 10     male  associate's degree    reading    58      54      52
# 11     male  associate's degree    reading    40      52      43
# 12   female         high school    reading    65      81      73
# 13     male        some college  completed    78      72      70
# 14   female     master's degree    reading    50      53      58
# 15   female    some high school    reading    69      75      78
# 16     male         high school    reading    88      89      86
# 17   female    some high school    reading    18      32      28
# 18     male     master's degree  completed    46      42      46
# 19   female  associate's degree    reading    54      58      61
# 20     male         high school    reading    66      69      63
# 21   female        some college  completed    65      75      70
# 22     male        some college    reading    44      54      53
# 23   female    some high school    reading    69      73      73
# 24     male   bachelor's degree  completed    74      71      80
# 25     male     master's degree    reading    73      74      72
# 26     male        some college    reading    69      54      55
# 27   female   bachelor's degree    reading    67      69      75
# 28     male         high school    reading    70      70      65
# 29   female     master's degree    reading    62      70      75
# ..      ...                 ...        ...   ...     ...     ...
# 970  female   bachelor's degree    reading    89     100     100
# 971    male    some high school  completed    78      72      69
# 972  female         high school  completed    53      50      60
# 973  female        some college    reading    49      65      61
# 974  female        some college    reading    54      63      67
# 975  female        some college  completed    64      82      77
# 976    male        some college  completed    60      62      60
# 977    male  associate's degree    reading    62      65      58
# 978    male         high school  completed    55      41      48
# 979  female  associate's degree    reading    91      95      94
# 980  female         high school    reading     8      24      23
# 981    male    some high school    reading    81      78      78
# 982    male    some high school  completed    79      85      86
# 983  female        some college  completed    78      87      91
# 984  female    some high school    reading    74      75      82
# 985    male         high school    reading    57      51      54
# 986  female  associate's degree    reading    40      59      51
# 987    male    some high school  completed    81      75      76
# 988  female    some high school    reading    44      45      45
# 989  female        some college  completed    67      86      83
# 990    male         high school  completed    86      81      75
# 991  female    some high school  completed    65      82      78
# 992  female  associate's degree    reading    55      76      76
# 993  female   bachelor's degree    reading    62      72      74
# 994    male         high school    reading    63      63      62
# 995  female     master's degree  completed    88      99      95
# 996    male         high school    reading    62      55      55
# 997  female         high school  completed    59      71      65
# 998  female        some college  completed    68      78      77
# 999  female        some college    reading    77      86      86
#
# [1000 rows x 6 columns]

# %%
df.sub([1000 for var in range(1000)],axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1496         try:
# -> 1497             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1498         except TypeError:
#
# C:\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# C:\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# C:\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-250-ac2387577a86> in <module>()
# ----> 1 df.sub([1000 for var in range(1000)],axis=0)
#
# C:\Anaconda3\lib\site-packages\pandas\core\ops.py in f(self, other, axis, level, fill_value)
#    1552             return _combine_series_frame(self, other, na_op,
#    1553                                          fill_value=fill_value, axis=axis,
# -> 1554                                          level=level, try_cast=True)
#    1555         else:
#    1556             if fill_value is not None:
#
# C:\Anaconda3\lib\site-packages\pandas\core\ops.py in _combine_series_frame(self, other, func, fill_value, axis, level, try_cast)
#    1422         axis = self._get_axis_number(axis)
#    1423         if axis == 0:
# -> 1424             return self._combine_match_index(other, func, level=level)
#    1425         else:
#    1426             return self._combine_match_columns(other, func, level=level,
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in _combine_match_index(self, other, func, level)
#    4760         left, right = self.align(other, join='outer', axis=0, level=level,
#    4761                                  copy=False)
# -> 4762         new_data = func(left.values.T, right.values).T
#    4763         return self._constructor(new_data,
#    4764                                  index=left.index, columns=self.columns,
#
# C:\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1502                 result = np.empty(x.size, dtype=dtype)
#    1503                 yrav = y.ravel()
# -> 1504                 mask = notna(xrav) & notna(yrav)
#    1505                 xrav = xrav[mask]
#    1506
#
# ValueError: operands could not be broadcast together with shapes (6000,) (1000,)

# %%
import math
mean = df['math'].mean()
df[['wscore','math']].apply(lambda x:x-mean)
# Out:
#      wscore    math
# 0     7.911   5.911
# 1    21.911   2.911
# 2    26.911  23.911
# 3   -22.089 -19.089
# 4     8.911   9.911
# 5    11.911   4.911
# 6    25.911  21.911
# 7   -27.089 -26.089
# 8     0.911  -2.089
# 9   -16.089 -28.089
# 10  -14.089  -8.089
# 11  -23.089 -26.089
# 12    6.911  -1.089
# 13    3.911  11.911
# 14   -8.089 -16.089
# 15   11.911   2.911
# 16   19.911  21.911
# 17  -38.089 -48.089
# 18  -20.089 -20.089
# 19   -5.089 -12.089
# 20   -3.089  -0.089
# 21    3.911  -1.089
# 22  -13.089 -22.089
# 23    6.911   2.911
# 24   13.911   7.911
# 25    5.911   6.911
# 26  -11.089   2.911
# 27    8.911   0.911
# 28   -1.089   3.911
# 29    8.911  -4.089
# ..      ...     ...
# 970  33.911  22.911
# 971   2.911  11.911
# 972  -6.089 -13.089
# 973  -5.089 -17.089
# 974   0.911 -12.089
# 975  10.911  -2.089
# 976  -6.089  -6.089
# 977  -8.089  -4.089
# 978 -18.089 -11.089
# 979  27.911  24.911
# 980 -43.089 -58.089
# 981  11.911  14.911
# 982  19.911  12.911
# 983  24.911  11.911
# 984  15.911   7.911
# 985 -12.089  -9.089
# 986 -15.089 -26.089
# 987   9.911  14.911
# 988 -21.089 -22.089
# 989  16.911   0.911
# 990   8.911  19.911
# 991  11.911  -1.089
# 992   9.911 -11.089
# 993   7.911  -4.089
# 994  -4.089  -3.089
# 995  28.911  21.911
# 996 -11.089  -4.089
# 997  -1.089  -7.089
# 998  10.911   1.911
# 999  19.911  10.911
#
# [1000 rows x 2 columns]
