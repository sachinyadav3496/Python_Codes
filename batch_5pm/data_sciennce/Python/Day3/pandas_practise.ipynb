# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
arr = np.random.random(100)*7.5

# %%
arr.mean()
# Out:
# 3.643078850440084

# %%
series = pd.Series(data=arr)

# %%
series
# Out:
# 0     3.035822
# 1     7.495981
# 2     7.173618
# 3     3.120520
# 4     5.069334
# 5     6.213088
# 6     5.442914
# 7     0.647885
# 8     5.583524
# 9     2.870224
# 10    5.468686
# 11    4.795318
# 12    3.994008
# 13    2.667123
# 14    4.769326
# 15    0.104381
# 16    4.344104
# 17    5.070092
# 18    7.304584
# 19    4.872350
# 20    5.566924
# 21    7.193314
# 22    6.649104
# 23    2.016875
# 24    4.900814
# 25    0.648580
# 26    3.866375
# 27    2.554738
# 28    2.048301
# 29    4.555118
#         ...
# 70    4.577762
# 71    6.118622
# 72    0.266894
# 73    0.300784
# 74    3.705815
# 75    2.991177
# 76    0.264229
# 77    5.435380
# 78    0.717730
# 79    2.708146
# 80    4.954311
# 81    2.557443
# 82    1.270437
# 83    6.153578
# 84    0.853944
# 85    0.374179
# 86    4.772404
# 87    3.234179
# 88    6.704465
# 89    5.252527
# 90    4.021296
# 91    5.977402
# 92    1.122211
# 93    0.066539
# 94    1.607668
# 95    2.325673
# 96    3.952389
# 97    7.025982
# ...

# %%
series.plot(kind='bar')

# %%
s = pd.Series([2,3,5,2,3,3,3,3,5,4,3,2,1,1,2,3,4,5])

# %%
s.plot(kind='bar')

# %%
s.hist()

# %%
series.hist()

# %%
s.value_counts()
# Out:
# 3    7
# 2    4
# 5    3
# 4    2
# 1    2
# dtype: int64

# %%
plt.scatter(s.unique(),s.value_counts())
plt.grid()
plt.show()

# %%
s.unique().sort()

# %%
s
# Out:
# 0     2
# 1     3
# 2     5
# 3     2
# 4     3
# 5     3
# 6     3
# 7     3
# 8     5
# 9     4
# 10    3
# 11    2
# 12    1
# 13    1
# 14    2
# 15    3
# 16    4
# 17    5
# dtype: int64

# %%
data = { 
    'Name' : [ 'x','y','z','p','q','r','s','t','p'],
    'Age' : [ 22,25,18,16,32,28,18,19,21],
    'Height' : [ 5.5,2.5,6.2,5.10,5.5,5.6,5.7,5.5,5.8],
    'Weight' : [ 50,60,65,75,40,56,65,78,87]
    
            }

df = pd.DataFrame(data=data,index=range(1,10),columns=data.keys())

# %%
df
# Out:
#   Name  Age  Height  Weight
# 1    x   22     5.5      50
# 2    y   25     2.5      60
# 3    z   18     6.2      65
# 4    p   16     5.1      75
# 5    q   32     5.5      40
# 6    r   28     5.6      56
# 7    s   18     5.7      65
# 8    t   19     5.5      78
# 9    p   21     5.8      87

# %%
df.plot()

# %%
date = [ '2018/12/10','2018/12/11','2018/12/12','2018/12/13','2018/12/14',]

# %%
s = pd.Series(date,dtype='datetime64[ns]')

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.dtype
# Out:
# dtype('<M8[ns]')

# %%
print(s)
# Out:
# 0   2018-12-10
# 1   2018-12-11
# 2   2018-12-12
# 3   2018-12-13
# 4   2018-12-14
# dtype: datetime64[ns]

# %%
d = { 
    'one' : np.random.normal(30.5,5.0,1000),
    'two' : np.random.normal(25,2.5,1000),
    'three' : np.random.binomial(25,.6,1000)
    }

# %%
df = pd.DataFrame(data=d,columns=d.keys())

# %%
df
# Out:
#            one        two  three
# 0    26.972263  28.901913     17
# 1    38.559602  23.214006     14
# 2    26.883320  27.745634     14
# 3    37.260856  23.357966     16
# 4    32.882206  23.477459     19
# 5    34.890419  22.642450     17
# 6    28.268352  22.981156     19
# 7    33.721792  25.392909     14
# 8    35.127322  26.499922     12
# 9    29.771198  29.187929     11
# 10   26.266947  27.546848     14
# 11   35.411334  22.250396     16
# 12   25.018889  31.538606     15
# 13   35.330957  25.219633     13
# 14   38.688671  22.491485     14
# 15   19.345674  23.715511     14
# 16   23.319629  21.720001     18
# 17   19.571943  24.002441     18
# 18   31.279503  26.976870     17
# 19   30.540781  21.307984     17
# 20   22.450487  22.470748     17
# 21   26.414367  17.727699     12
# 22   28.240240  27.046757     13
# 23   33.958744  20.487847     15
# 24   33.041780  27.777053     16
# 25   27.225002  28.250771     14
# 26   23.930079  28.245175     17
# ...

# %%
plt.plot(range(1000),df['one'],'r',df['two'],'g',df['three'])

# %%
df.head(5)
# Out:
#          one        two  three
# 0  26.972263  28.901913     17
# 1  38.559602  23.214006     14
# 2  26.883320  27.745634     14
# 3  37.260856  23.357966     16
# 4  32.882206  23.477459     19

# %%
df.tail(10)
# Out:
#            one        two  three
# 990  30.792731  26.321707     14
# 991  34.355365  24.614721     15
# 992  25.739417  26.161430     14
# 993  29.064005  25.445732     16
# 994  28.647598  23.317624     17
# 995  25.989389  21.858818     17
# 996  31.334092  25.933285     15
# 997  27.704820  26.504296     17
# 998  34.609214  26.005945     18
# 999  27.239428  24.447984     12

# %%
df1 = df.head(30)

# %%
plt.plot(range(30),df1['one'],'r',df1['two'],'g',df1['three'])

# %%
df['one'].dtype
# Out:
# dtype('float64')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.columns
# Out:
# Index(['one', 'two', 'three'], dtype='object')

# %%
df.describe()
# Out:
#                one          two        three
# count  1000.000000  1000.000000  1000.000000
# mean     30.471191    25.058003    15.010000
# std       4.965042     2.474357     2.528298
# min      15.129349    16.468776     6.000000
# 25%      27.224463    23.356155    13.000000
# 50%      30.603213    25.132585    15.000000
# 75%      33.825421    26.655041    17.000000
# max      45.638662    33.423670    23.000000

# %%
df.T
# Out:
#              0          1          2          3          4          5    \
# one    26.972263  38.559602  26.883320  37.260856  32.882206  34.890419
# two    28.901913  23.214006  27.745634  23.357966  23.477459  22.642450
# three  17.000000  14.000000  14.000000  16.000000  19.000000  17.000000
#
#              6          7          8          9      ...            990  \
# one    28.268352  33.721792  35.127322  29.771198    ...      30.792731
# two    22.981156  25.392909  26.499922  29.187929    ...      26.321707
# three  19.000000  14.000000  12.000000  11.000000    ...      14.000000
#
#              991        992        993        994        995        996  \
# one    34.355365  25.739417  29.064005  28.647598  25.989389  31.334092
# two    24.614721  26.161430  25.445732  23.317624  21.858818  25.933285
# three  15.000000  14.000000  16.000000  17.000000  17.000000  15.000000
#
#              997        998        999
# one    27.704820  34.609214  27.239428
# ...

# %%
from random import randint
df = pd.DataFrame(data=[[randint(5,50) for var in range(30)],[randint(5,50) for var in range(30)],[randint(5,50) for var in range(30)]])

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df = df.T

# %%
df
# Out:
#      0   1   2
# 0   18  13  40
# 1   13  31  41
# 2   20  15  47
# 3   24  17  28
# 4   26  39  42
# 5   13   7  11
# 6   42  34  19
# 7   31  38  41
# 8   27  32  42
# 9   38  39  38
# 10  30  49  23
# 11  48  26  16
# 12  31  21  45
# 13  22  35  42
# 14  21  25  12
# 15  10  47  16
# 16  28  41  50
# 17  30  49  24
# 18  43  18  42
# 19   7  42  10
# 20  31  20  49
# 21   8  39  16
# 22  46  43  26
# 23  38  25  10
# 24  45  41  24
# 25  46  39  14
# 26  30  36  10
# 27  38  42  36
# 28  27  34   5
# 29  25  20  16

# %%
df.columns = [ 'third','second','first']

# %%
df.index  = range(30,0,-1)

# %%
df
# Out:
#     third  second  first
# 30     18      13     40
# 29     13      31     41
# 28     20      15     47
# 27     24      17     28
# 26     26      39     42
# 25     13       7     11
# 24     42      34     19
# 23     31      38     41
# 22     27      32     42
# 21     38      39     38
# 20     30      49     23
# 19     48      26     16
# 18     31      21     45
# 17     22      35     42
# 16     21      25     12
# 15     10      47     16
# 14     28      41     50
# 13     30      49     24
# 12     43      18     42
# 11      7      42     10
# 10     31      20     49
# 9       8      39     16
# 8      46      43     26
# 7      38      25     10
# 6      45      41     24
# 5      46      39     14
# 4      30      36     10
# 3      38      42     36
# 2      27      34      5
# 1      25      20     16

# %%
df.sort_index(axis=0)
# Out:
#     third  second  first
# 1      25      20     16
# 2      27      34      5
# 3      38      42     36
# 4      30      36     10
# 5      46      39     14
# 6      45      41     24
# 7      38      25     10
# 8      46      43     26
# 9       8      39     16
# 10     31      20     49
# 11      7      42     10
# 12     43      18     42
# 13     30      49     24
# 14     28      41     50
# 15     10      47     16
# 16     21      25     12
# 17     22      35     42
# 18     31      21     45
# 19     48      26     16
# 20     30      49     23
# 21     38      39     38
# 22     27      32     42
# 23     31      38     41
# 24     42      34     19
# 25     13       7     11
# 26     26      39     42
# 27     24      17     28
# 28     20      15     47
# 29     13      31     41
# 30     18      13     40

# %%
df.sort_index(axis=1)
# Out:
#     first  second  third
# 30     40      13     18
# 29     41      31     13
# 28     47      15     20
# 27     28      17     24
# 26     42      39     26
# 25     11       7     13
# 24     19      34     42
# 23     41      38     31
# 22     42      32     27
# 21     38      39     38
# 20     23      49     30
# 19     16      26     48
# 18     45      21     31
# 17     42      35     22
# 16     12      25     21
# 15     16      47     10
# 14     50      41     28
# 13     24      49     30
# 12     42      18     43
# 11     10      42      7
# 10     49      20     31
# 9      16      39      8
# 8      26      43     46
# 7      10      25     38
# 6      24      41     45
# 5      14      39     46
# 4      10      36     30
# 3      36      42     38
# 2       5      34     27
# 1      16      20     25

# %%
df.sort_values(axis=0,by='second',ascending=False)
# Out:
#     third  second  first
# 20     30      49     23
# 13     30      49     24
# 15     10      47     16
# 8      46      43     26
# 3      38      42     36
# 11      7      42     10
# 14     28      41     50
# 6      45      41     24
# 26     26      39     42
# 9       8      39     16
# 21     38      39     38
# 5      46      39     14
# 23     31      38     41
# 4      30      36     10
# 17     22      35     42
# 2      27      34      5
# 24     42      34     19
# 22     27      32     42
# 29     13      31     41
# 19     48      26     16
# 16     21      25     12
# 7      38      25     10
# 18     31      21     45
# 1      25      20     16
# 10     31      20     49
# 12     43      18     42
# 27     24      17     28
# 28     20      15     47
# 30     18      13     40
# 25     13       7     11

# %%
plt.plot(df['second'],df['first'],'r',df['third'],'g')

# %%
df
# Out:
#     third  second  first
# 30     18      13     40
# 29     13      31     41
# 28     20      15     47
# 27     24      17     28
# 26     26      39     42
# 25     13       7     11
# 24     42      34     19
# 23     31      38     41
# 22     27      32     42
# 21     38      39     38
# 20     30      49     23
# 19     48      26     16
# 18     31      21     45
# 17     22      35     42
# 16     21      25     12
# 15     10      47     16
# 14     28      41     50
# 13     30      49     24
# 12     43      18     42
# 11      7      42     10
# 10     31      20     49
# 9       8      39     16
# 8      46      43     26
# 7      38      25     10
# 6      45      41     24
# 5      46      39     14
# 4      30      36     10
# 3      38      42     36
# 2      27      34      5
# 1      25      20     16

# %%
df.index = range(30)
df = df.sort_index(axis=0)
print(df)
# Out:
#     third  second  first
# 0      25      20     16
# 1      27      34      5
# 2      38      42     36
# 3      30      36     10
# 4      46      39     14
# 5      45      41     24
# 6      38      25     10
# 7      46      43     26
# 8       8      39     16
# 9      31      20     49
# 10      7      42     10
# 11     43      18     42
# 12     30      49     24
# 13     28      41     50
# 14     10      47     16
# 15     21      25     12
# 16     22      35     42
# 17     31      21     45
# 18     48      26     16
# 19     30      49     23
# 20     38      39     38
# 21     27      32     42
# 22     31      38     41
# 23     42      34     19
# 24     13       7     11
# 25     26      39     42
# 26     24      17     28
# 27     20      15     47
# 28     13      31     41
# 29     18      13     40

# %%
df[5:25:3]
# Out:
#     third  second  first
# 5      45      41     24
# 8       8      39     16
# 11     43      18     42
# 14     10      47     16
# 17     31      21     45
# 20     38      39     38
# 23     42      34     19

# %%
df.index = pd.date_range('20181110',periods=30)

# %%
df.sort_index(axis=0,ascending=False).sort_index(axis=1)[:5].describe()
# Out:
#            first     second      third
# count   5.000000   5.000000   5.000000
# mean   39.600000  23.000000  20.200000
# std     7.021396  11.401754   5.118594
# min    28.000000  13.000000  13.000000
# 25%    40.000000  15.000000  18.000000
# 50%    41.000000  17.000000  20.000000
# 75%    42.000000  31.000000  24.000000
# max    47.000000  39.000000  26.000000

# %%
df
# Out:
#             third  second  first
# 2018-11-10     25      20     16
# 2018-11-11     27      34      5
# 2018-11-12     38      42     36
# 2018-11-13     30      36     10
# 2018-11-14     46      39     14
# 2018-11-15     45      41     24
# 2018-11-16     38      25     10
# 2018-11-17     46      43     26
# 2018-11-18      8      39     16
# 2018-11-19     31      20     49
# 2018-11-20      7      42     10
# 2018-11-21     43      18     42
# 2018-11-22     30      49     24
# 2018-11-23     28      41     50
# 2018-11-24     10      47     16
# 2018-11-25     21      25     12
# 2018-11-26     22      35     42
# 2018-11-27     31      21     45
# 2018-11-28     48      26     16
# 2018-11-29     30      49     23
# 2018-11-30     38      39     38
# 2018-12-01     27      32     42
# 2018-12-02     31      38     41
# 2018-12-03     42      34     19
# 2018-12-04     13       7     11
# 2018-12-05     26      39     42
# 2018-12-06     24      17     28
# ...

# %%
df[::5]
# Out:
#             third  second  first
# 2018-11-10     25      20     16
# 2018-11-15     45      41     24
# 2018-11-20      7      42     10
# 2018-11-25     21      25     12
# 2018-11-30     38      39     38
# 2018-12-05     26      39     42

# %%
df['20181110':'20181120']
# Out:
#             third  second  first
# 2018-11-10     25      20     16
# 2018-11-11     27      34      5
# 2018-11-12     38      42     36
# 2018-11-13     30      36     10
# 2018-11-14     46      39     14
# 2018-11-15     45      41     24
# 2018-11-16     38      25     10
# 2018-11-17     46      43     26
# 2018-11-18      8      39     16
# 2018-11-19     31      20     49
# 2018-11-20      7      42     10
